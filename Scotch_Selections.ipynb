# %% [markdown]
# # Searching for Superior Scotch
#
# My mission for this project is to:
# A. Clean a dataset
#
# B. Perform exploratory data analysis:
#
#     the distribution of review scores,
#     the descriptive statistics of prices per review score,
#     identify the scotch whiskys with the highest review scores
# C. Answer a few questions:
#
#     1. How do the 3 scotch categories perform according to review scores?
#     2. Which category is produced and sold in the greatest quantity?
#     3. Which scotches provide the best overall value?
#     4. My friend was upset that a particular bottle wasn't in the best values list, so why not?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

scotch = pd.read_csv('scotch_reviews_2020.csv')

# %% [markdown]
# # View the data

# %%
scotch.info()
scotch.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2247 entries, 0 to 2246
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2247 non-null   int64
#  1   name                 2247 non-null   object
#  2   category             2247 non-null   object
#  3   review.point         2247 non-null   int64
#  4   price                2247 non-null   object
#  5   currency             2247 non-null   object
#  6   description.1.2247.  2208 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 123.0+ KB
#    id                                               name  \
# 0   1      Black Bowmore 42 year old 1964 vintage, 40.5%
# 1   2        Bowmore 46 year old (distilled 1964), 42.9%
# 2   3                     Johnnie Walker Blue Label, 40%
# 3   4    Glenlivet Cellar Collection 1969 vintage, 50.8%
# 4   5  The Macallan 29 year old 1976 Vintage (Cask #1...
#
#                 category  review.point  price currency  \
# 0     Single Malt Scotch            97   4500        $
# 1     Single Malt Scotch            97  13500        $
# 2  Blended Scotch Whisky            97    225        $
# 3     Single Malt Scotch            96    750        $
# 4     Single Malt Scotch            96  1,500        $
#
#                                  description.1.2247.
# 0  What impresses me most is how this whisky evol...
# 1  There have been some legendary Bowmores from t...
# 2  Magnificently powerful and intense. Caramels, ...
# 3  It’s great that Glenlivet releases whiskies un...
# 4  Classic sherry cask-aged Macallan. Antique amb...

# %% [markdown]
# ## Clean the data
#
# Rename weird columns, and check to see if currency is all in $. If so, I'll change the name of the price column and drop the currency column...

# %%
scotch['currency'].unique()
# Out:
# array(['$'], dtype=object)

# %%
scotch['currency'].nunique()
# Out:
# 1

# %%
scotch.rename(columns={'review.point': 'points', 
                       'price': 'USD', 
                       'description.1.2247.': 'review'}, inplace=True)
scotch.drop('currency', axis=1, inplace=True)

# %%
scotch['USD'] = pd.to_numeric(scotch['USD'], errors='coerce')
scotch['USD'].isna().sum()
# Out:
# 116

# %%
scotch.dropna(subset='USD', inplace=True)
scotch['USD'].isna().sum()
# Out:
# 0

# %%
scotch['USD'] = scotch['USD'].astype(int)

# %% [markdown]
# # Check for duplicate rows

# %%
scotch.duplicated(subset='name').sum()
# Out:
# 59

# %%
scotch.drop_duplicates(subset='name', keep='first', inplace=True)
scotch.duplicated(subset='name').sum()
# Out:
# 0

# %%
scotch.info()
scotch.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2072 entries, 0 to 2246
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        2072 non-null   int64
#  1   name      2072 non-null   object
#  2   category  2072 non-null   object
#  3   points    2072 non-null   int64
#  4   USD       2072 non-null   int32
#  5   review    2037 non-null   object
# dtypes: int32(1), int64(2), object(3)
# memory usage: 105.2+ KB
#     id                                             name  \
# 0    1    Black Bowmore 42 year old 1964 vintage, 40.5%
# 1    2      Bowmore 46 year old (distilled 1964), 42.9%
# 2    3                   Johnnie Walker Blue Label, 40%
# 3    4  Glenlivet Cellar Collection 1969 vintage, 50.8%
# 6    7                Gold Bowmore 1964 vintage, 42.4%
# 7    8                       Bowmore 40 year old, 44.8%
# 8    9                   Compass Box The General, 53.4%
# 10  11                          Chivas Regal Ultis, 40%
# 11  12                         Chivas, 18 year old, 40%
# 12  13             Johnnie Walker Blue Anniversary, 60%
#
#                       category  points    USD  \
# 0           Single Malt Scotch      97   4500
# 1           Single Malt Scotch      97  13500
# 2        Blended Scotch Whisky      97    225
# 3           Single Malt Scotch      96    750
# 6           Single Malt Scotch      96   6250
# 7           Single Malt Scotch      96  11000
# 8   Blended Malt Scotch Whisky      96    325
# 10  Blended Malt Scotch Whisky      96    160
# 11       Blended Scotch Whisky      95     70
# 12       Blended Scotch Whisky      95   3500
#
#                                                review
# 0   What impresses me most is how this whisky evol...
# 1   There have been some legendary Bowmores from t...
# 2   Magnificently powerful and intense. Caramels, ...
# 3   It’s great that Glenlivet releases whiskies un...
# 6   Deep gold color. Surprisingly lively on the no...
# 7   Definitely showing its age, but not in a bad w...
# 8   With a name inspired by a 1926 Buster Keaton m...
# 10  Captivating, enticing, and wonderfully charmin...
# 11  An essay in balance on both the aroma and pala...
# 12  Formulated to celebrate the 200th anniversary ...

# %%
scotch.describe()
# Out:
#                 id       points            USD
# count  2072.000000  2072.000000    2072.000000
# mean   1152.914575    88.338320     361.391892
# std     639.771280     2.890555    3617.160759
# min       1.000000    83.000000      10.000000
# 25%     606.750000    86.000000      68.000000
# 50%    1166.500000    88.000000     110.000000
# 75%    1703.250000    90.000000     200.000000
# max    2247.000000    97.000000  157000.000000

# %% [markdown]
# ## I'll look at the review points distribution.

# %%
scotch['points'].value_counts()
# Out:
# points
# 88    261
# 87    257
# 89    237
# 90    230
# 86    212
# 85    196
# 84    154
# 91    148
# 92    144
# 93    100
# 94     57
# 83     43
# 95     25
# 96      5
# 97      3
# Name: count, dtype: int64

# %%
with sns.axes_style(style='whitegrid'):
    f = sns.displot(data=scotch, x='points', kde=True, bins=15)
# Out:
# C:\Users\david\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Descriptive statistics on prices per point rating.

# %%
scotch.groupby('points')['USD'].describe()
# Out:
#         count         mean           std    min      25%     50%      75%  \
# points
# 83       43.0   136.023256    145.113008   30.0    67.50    90.0   157.50
# 84      154.0   124.285714    184.702471   13.0    63.50    80.0   124.50
# 85      196.0   140.183673    250.798186   10.0    60.00    84.0   133.00
# 86      212.0   140.867925    173.261278   20.0    61.50    95.0   130.00
# 87      257.0   204.762646    949.631776   16.0    59.00    80.0   140.00
# 88      261.0   178.969349    318.646065   13.0    65.00   100.0   160.00
# 89      237.0   228.257384    623.441342   25.0    70.00   114.0   181.00
# 90      230.0   221.595652    300.359678   22.0    70.00   120.0   249.00
# 91      148.0   497.513514   2058.325138   35.0   100.00   151.0   335.00
# 92      144.0   422.173611   1131.544488   45.0    95.00   151.0   339.50
# 93      100.0  2046.070000  15670.294086   34.0   119.75   212.5   551.75
# 94       57.0   707.438596   1779.315448   47.0   130.00   225.0   400.00
# 95       25.0  1840.400000   5275.807979   70.0   215.00   400.0   790.00
# 96        5.0  3697.000000   4806.692730  160.0   325.00   750.0  6250.00
# 97        3.0  6075.000000   6776.199156  225.0  2362.50  4500.0  9000.00
#
#              max
# points
# 83         900.0
# 84        1900.0
# 85        3000.0
# 86        1250.0
# 87       14999.0
# 88        3378.0
# 89        7000.0
# 90        2500.0
# 91       23427.0
# 92       12000.0
# 93      157000.0
# 94       11824.0
# 95       26650.0
# 96       11000.0
# 97       13500.0

# %% [markdown]
# ### Note from table above: There is a 97 reviewed whisky for 225 USD. Considering there are bottles for magnitude orders more, 225 USD is relatively inexpensive for such a great rating. Maybe I'll try to find out what it is...

# %%
scotch.query("points == 97")
# Out:
#    id                                           name               category  \
# 0   1  Black Bowmore 42 year old 1964 vintage, 40.5%     Single Malt Scotch
# 1   2    Bowmore 46 year old (distilled 1964), 42.9%     Single Malt Scotch
# 2   3                 Johnnie Walker Blue Label, 40%  Blended Scotch Whisky
#
#    points    USD                                             review
# 0      97   4500  What impresses me most is how this whisky evol...
# 1      97  13500  There have been some legendary Bowmores from t...
# 2      97    225  Magnificently powerful and intense. Caramels, ...

# %% [markdown]
# ## Now I'll try to put prices into bins, and sort the dataframe by points and price bins...

# %%
price_bins = pd.qcut(scotch['USD'], 7, precision=0)
scotch.groupby(['points', price_bins])['name'].count().unstack()
# Out:
# C:\Users\david\AppData\Local\Temp\ipykernel_20876\1288445346.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   scotch.groupby(['points', price_bins])['name'].count().unstack()
# USD     (9.0, 55.0]  (55.0, 72.0]  (72.0, 96.0]  (96.0, 125.0]  \
# points
# 83                9             5            10              5
# 84               29            29            38             22
# 85               46            33            36             26
# 86               43            31            34             43
# 87               60            45            41             29
# 88               41            43            44             39
# 89               35            25            30             44
# 90               27            33            21             40
# 91               11            11            14             21
# 92                8            13            17             17
# 93                4             6            10              8
# 94                1             3             2              8
# 95                0             1             1              2
# 96                0             0             0              0
# 97                0             0             0              0
#
# USD     (125.0, 175.0]  (175.0, 350.0]  (350.0, 157000.0]
# points
# 83                   6               6                  2
# 84                  18              11                  7
# 85                  28              14                 13
# 86                  31              12                 18
# 87                  31              30                 21
# 88                  35              33                 26
# 89                  41              40                 22
# 90                  26              48                 35
# 91                  27              31                 33
# 92                  24              30                 35
# 93                  18              19                 35
# 94                   7              20                 16
# 95                   0               7                 14
# 96                   1               1                  3
# 97                   0               1                  2

# %% [markdown]
# # Analysis
#
# Question 1: How do the categories stack up against each other?

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot(data=scotch, x='category', y='points', kind='box', palette='colorblind', legend=False)
    g.set_axis_labels('', 'Points')
    g.set_xticklabels(['Single Malt', 'Blended', 'Blended Malt'])
    g.fig.suptitle('Review Points per Whisky Category')
plt.show()

# %% [markdown]
# ### Question 2: What types of whisky are being sold?

# %%
with sns.axes_style('darkgrid'):
    h = sns.catplot(data=scotch, x='category', kind='count', hue='category', palette='colorblind', alpha=0.75, legend=False)
    h.set_axis_labels('', 'Count')
    h.set_xticklabels(['Single Malt', 'Blended', 'Blended Malt'])
    h.fig.suptitle('Brands Reviewed per Whisky Category')
plt.show()

# %% [markdown]
# ### Question 3: Now, I want to determine which scotches have the best value. First, I'll filter brands that fit into a particular price and rating range (which I just made up myself, no science involved). I want bottles that are less than or equal to 125 and a rating of 93 or higher...

# %%
scotch_filter = scotch.query("USD <= 125 & points >= 93")
scotch_filter.info()
scotch_filter
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 11 to 234
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        46 non-null     int64
#  1   name      46 non-null     object
#  2   category  46 non-null     object
#  3   points    46 non-null     int64
#  4   USD       46 non-null     int32
#  5   review    45 non-null     object
# dtypes: int32(1), int64(2), object(3)
# memory usage: 2.3+ KB
#       id                                               name  \
# 11    12                           Chivas, 18 year old, 40%
# 26    27  Compass Box Flaming Heart (10th Anniversary bo...
# 31    32  Compass Box The Peat Monster 10th Anniversary ...
# 34    35                         Ardbeg Corryvreckan, 57.1%
# 51    52             The Macallan 17 year old Fine Oak, 43%
# 54    55                    The Antiquary, 21 year old, 43%
# 59    60                  Compass Box The Peat Monster, 46%
# 60    61                         Laphroaig Triple Wood, 48%
# 63    64  Lagavulin 12 year old (Diageo Special Releases...
# 65    66                     Highland Park 18 year old, 43%
# 67    68  Blue Hanger 6th Release Berry Bros. & Rudd, 45.6%
# 77    78  Chivas Regal 18 year old Ultimate Cask Collect...
# 79    80                     Glenmorangie Astar 2017, 52.5%
# 83    84                            Ardbeg Uigeadail, 54.2%
# 91    92             Glenmorangie Astar 2017 Release, 52.5%
# 96    97  Laphroaig 10 year old Cask Strength (Batch 011...
# 104  105                     Benriach The Smoky Twelve, 46%
# 109  110               Ardbeg 5 year old Wee Beastie, 47.4%
# 110  111                     Black Bottle, 10 year old, 43%
# 114  115            Bowmore 16 year old 1989 vintage, 51.8%
# 121  122                 Glenlivet Archive 21 year old, 43%
# 125  126  Gordon & MacPhail (distilled at Mortlach), 11 ...
# 130  131                        Talisker 18 year old, 45.8%
# 131  132                   Highland Park 21 year old, 47.5%
# 136  137                          Glenmorangie Astar, 57.1%
# 141  142                       GlenDronach 15 year old, 46%
# 153  154                         Compass Box Oak Cross, 46%
# 154  155       Douglas Laing Big Peat Christmas 2013, 54.9%
# 171  172                  Sheep Dip Islay Blended Malt, 40%
# 184  185                                Ardbeg An Oa, 46.6%
# 190  191               Black Snake Vat 6 Third Venom, 60.2%
# 191  192  Laphroaig 10 year old Cask Strength (Batch 010...
# 194  195                 Buchanan’s Select 15 year old, 40%
# 200  201                    Port Charlotte 10 year old, 50%
# 201  202                Tamdhu Batch Strength (#002), 58.5%
# 207  208     Kilchoman STR Cask-Matured (2019 Release), 50%
# 208  209  Glen Scotia 2003 Campbeltown Malts Festival Ru...
# 211  212  Aberlour A’bunadh Alba Cask Strength (Batch #0...
# 213  214                         Laphroaig 16 year old, 48%
# 220  221                         Lagavulin 16 year old, 43%
# 224  225   Compass Box Great King Street Glasgow Blend, 43%
# 227  228  Aberfeldy 18 year old French Red Wine Cask-Fin...
# 228  229                   Glenmorangie A Tale of Cake, 46%
# 230  231  Talisker 8 year old (Diageo Special Releases 2...
# 233  234                          Balblair 15 year old, 46%
# 234  235   Glenmorangie 15 year old The Cadboll Estate, 43%
#
#                        category  points  USD  \
# 11        Blended Scotch Whisky      95   70
# 26   Blended Malt Scotch Whisky      95  105
# 31        Blended Scotch Whisky      95  120
# 34           Single Malt Scotch      95   90
# 51           Single Malt Scotch      94  120
# 54        Blended Scotch Whisky      94  100
# 59   Blended Malt Scotch Whisky      94   65
# 60           Single Malt Scotch      94  100
# 63           Single Malt Scotch      94  109
# 65           Single Malt Scotch      94  112
# 67   Blended Malt Scotch Whisky      94   84
# 77        Blended Scotch Whisky      94  120
# 79           Single Malt Scotch      94  100
# 83           Single Malt Scotch      94   80
# 91           Single Malt Scotch      94  100
# 96           Single Malt Scotch      94   70
# 104          Single Malt Scotch      94   65
# 109          Single Malt Scotch      94   47
# 110       Blended Scotch Whisky      93   34
# 114          Single Malt Scotch      93   90
# 121          Single Malt Scotch      93  100
# 125          Single Malt Scotch      93   80
# 130          Single Malt Scotch      93   65
# 131          Single Malt Scotch      93  100
# 136          Single Malt Scotch      93   85
# 141          Single Malt Scotch      93   95
# 153  Blended Malt Scotch Whisky      93   50
# 154  Blended Malt Scotch Whisky      93   76
# 171  Blended Malt Scotch Whisky      93   60
# 184          Single Malt Scotch      93   60
# 190          Single Malt Scotch      93  100
# 191          Single Malt Scotch      93   70
# 194  Blended Malt Scotch Whisky      93   50
# 200          Single Malt Scotch      93   65
# 201          Single Malt Scotch      93   90
# 207          Single Malt Scotch      93  120
# 208          Single Malt Scotch      93   90
# 211          Single Malt Scotch      93   90
# 213          Single Malt Scotch      93   90
# 220          Single Malt Scotch      93   65
# 224       Blended Scotch Whisky      93   40
# 227          Single Malt Scotch      93  120
# 228          Single Malt Scotch      93   99
# 230          Single Malt Scotch      93  119
# 233          Single Malt Scotch      93  120
# 234          Single Malt Scotch      93   85
#
#                                                 review
# 11   An essay in balance on both the aroma and pala...
# 26   A marriage of three different single malts, ag...
# 31   As you’d expect, solid peat is the first thing...
# 34   Part of the permanent Ardbeg range since 2008,...
# 51   Another of the Fine Oak series (aged in both b...
# 54   Drier than the 12 year old (reviewed below), w...
# 59   The formula for this whisky has changed slight...
# 60   This is the first time I’ve been up for review...
# 63   There’s precious little reticence about this b...
# 65   Introduced to the Highland Park portfolio in 1...
# 67   If you want proof that blended malts can be wo...
# 77   An auld alliance renewed, this gorgeous whisky...
# 79   This is the 15th Special Releases bottling of ...
# 83   The nose has honey, caramelized apples, Pixy S...
# 91   An innovative offering made with a proportion ...
# 96   Master blender Stephanie Macleod’s innovative ...
# 104  Rich sherried fruit aromas, machine oil, camph...
# 109  \r\n\r\nSpirit, not cask, drives this whisky’s...
# 110  \r\n\r\nBenriach is a sleeper of a single malt...
# 114  The last Balvenie Vintage whisky I tasted that...
# 121  An impressive single cask bottling of Glenfidd...
# 125  Gold color. Peaty, smoky, mature aromas, with ...
# 130  Aromatically fruity and quite full, with wonde...
# 131  Surprisingly clean and youthful for a 30 year ...
# 136  Straw/honey color. Light to medium weight, wit...
# 141  Port Ellen whiskies are just going to keep get...
# 153  Bright gold. Amazingly fresh fruits and quince...
# 154  The hits just keep on coming for Glenfarclas. ...
# 171  This cask strength, sherry cask matured expres...
# 184                                                NaN
# 190  Ardbeg's first standard release in nearly a de...
# 191  This 32 year old bottling was aged in twelve b...
# 194  A triumphant expression including whisky disti...
# 200  Butterscotch and smoke, with rewarding maritim...
# 201  A rare veteran bottling from Caol Ila, and the...
# 207  Historically used for blending, Tamdhu flies u...
# 208  Following the Spice Tree recipe of 60% Clyneli...
# 211  The nose yields baked apples, cherry blossom, ...
# 213  This was distilled in 2012 and matured in 43 r...
# 220  This release from independent bottler The Last...
# 224  Aged in newly toasted first-fill Pedro Ximénez...
# 227  Perhaps the most alluring name ever given to a...
# 228  This second release in the Flask Collection ep...
# 230  Honey, vanilla, poached pears in cream, driftw...
# 233  Creamy on the nose, with malt, toasted cereal,...
# 234  Generous and complex on all fronts: The nose i...

# %%
scotch_filter['USD'].agg(['max', 'min'])
# Out:
# max    120
# min     34
# Name: USD, dtype: int64

# %% [markdown]
# ## Now I will normalize "value" by dividing the price column by the points column. This should provide a relative value per bottle of scotch...

# %%
scotch['price_per_point'] = (scotch['USD'] / scotch['points']).round(2)
scotch.info()
scotch.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2072 entries, 0 to 2246
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2072 non-null   int64
#  1   name             2072 non-null   object
#  2   category         2072 non-null   object
#  3   points           2072 non-null   int64
#  4   USD              2072 non-null   int32
#  5   review           2037 non-null   object
#  6   price_per_point  2072 non-null   float64
# dtypes: float64(1), int32(1), int64(2), object(3)
# memory usage: 185.9+ KB
#    id                                             name               category  \
# 0   1    Black Bowmore 42 year old 1964 vintage, 40.5%     Single Malt Scotch
# 1   2      Bowmore 46 year old (distilled 1964), 42.9%     Single Malt Scotch
# 2   3                   Johnnie Walker Blue Label, 40%  Blended Scotch Whisky
# 3   4  Glenlivet Cellar Collection 1969 vintage, 50.8%     Single Malt Scotch
# 6   7                Gold Bowmore 1964 vintage, 42.4%      Single Malt Scotch
#
#    points    USD                                             review  \
# 0      97   4500  What impresses me most is how this whisky evol...
# 1      97  13500  There have been some legendary Bowmores from t...
# 2      97    225  Magnificently powerful and intense. Caramels, ...
# 3      96    750  It’s great that Glenlivet releases whiskies un...
# 6      96   6250  Deep gold color. Surprisingly lively on the no...
#
#    price_per_point
# 0            46.39
# 1           139.18
# 2             2.32
# 3             7.81
# 6            65.10

# %% [markdown]
# ## Now I'll sort by the best value. And I will make a new dataframe with only ratings above 92...

# %%
above_92 = scotch[scotch['points'] > 92]
above_92.sort_values('price_per_point')
# Out:
#       id                                               name  \
# 110  111                     Black Bottle, 10 year old, 43%
# 224  225   Compass Box Great King Street Glasgow Blend, 43%
# 109  110               Ardbeg 5 year old Wee Beastie, 47.4%
# 153  154                         Compass Box Oak Cross, 46%
# 194  195                 Buchanan’s Select 15 year old, 40%
# ..   ...                                                ...
# 7      8                         Bowmore 40 year old, 44.8%
# 70    71  Brora 40 year old Single Cask 1972 Vintage, 59.1%
# 1      2        Bowmore 46 year old (distilled 1964), 42.9%
# 29    30        Bowmore 50 year old (distilled 1961), 40.7%
# 151  152       Diamond Jubilee by John Walker & Sons, 42.5%
#
#                        category  points     USD  \
# 110       Blended Scotch Whisky      93      34
# 224       Blended Scotch Whisky      93      40
# 109          Single Malt Scotch      94      47
# 153  Blended Malt Scotch Whisky      93      50
# 194  Blended Malt Scotch Whisky      93      50
# ..                          ...     ...     ...
# 7            Single Malt Scotch      96   11000
# 70           Single Malt Scotch      94   11824
# 1            Single Malt Scotch      97   13500
# 29           Single Malt Scotch      95   26650
# 151       Blended Scotch Whisky      93  157000
#
#                                                 review  price_per_point
# 110  \r\n\r\nBenriach is a sleeper of a single malt...             0.37
# 224  Aged in newly toasted first-fill Pedro Ximénez...             0.43
# 109  \r\n\r\nSpirit, not cask, drives this whisky’s...             0.50
# 153  Bright gold. Amazingly fresh fruits and quince...             0.54
# 194  A triumphant expression including whisky disti...             0.54
# ..                                                 ...              ...
# 7    Definitely showing its age, but not in a bad w...           114.58
# 70   Just 160 bottles of 1972 Brora are available t...           125.79
# 1    There have been some legendary Bowmores from t...           139.18
# 29   The whisky is sensational, a glorious mix of g...           280.53
# 151  Bowmore lovers rarely get excited about the sm...          1688.17
#
# [190 rows x 7 columns]

# %% [markdown]
# ## Question 4: My friend asked specifically about the Macallan 12 year and Macallan 18 year scotch whiskys so I subsetted for those...

# %%
scotch[scotch['name'].str.contains('acallan') & scotch['name'].str.contains('12|18')]
# Out:
#         id                                               name  \
# 336    337  The Macallan 18 year old Sherry Oak (2017 Edit...
# 362    363  Macallan 18 year old Sherry Oak (2018 Edition)...
# 389    390              Macallan 18 year old Double Cask, 43%
# 436    437           The Macallan 18 year old Sherry Oak, 43%
# 598    599                   The Macallan 1861 Replica, 42.7%
# 706    707          The Macallan 12 year old Double Cask, 40%
# 775    776              Macallan 12 year old Double Cask, 43%
# 1290  1291              Macallan 12 year old Triple Cask, 40%
# 1590  1591               Macallan 12 year old Sherry Oak, 43%
#
#                 category  points  USD  \
# 336   Single Malt Scotch      92  294
# 362   Single Malt Scotch      92  320
# 389   Single Malt Scotch      92  330
# 436   Single Malt Scotch      91  118
# 598   Single Malt Scotch      90  180
# 706   Single Malt Scotch      90   65
# 775   Single Malt Scotch      90   65
# 1290  Single Malt Scotch      88   65
# 1590  Single Malt Scotch      87   70
#
#                                                  review  price_per_point
# 336   This was initially matured in American oak bou...             3.20
# 362   Terroir and provenance are keenly debated in m...             3.48
# 389   This expression was distilled from malt peated...             3.59
# 436   One of the finest Balvenie 15 year olds I’ve t...             1.30
# 598   Independent bottlings of Cragganmore are hard ...             2.00
# 706   A fantastically earthy whisky bristling with r...             0.72
# 775   The nose offers rubbery-sweet peat and an arra...             0.72
# 1290  Lighter in character than the 50 year old, bat...             0.74
# 1590  Part of the Jura range exhibiting ‘sweetness a...             0.80

# %% [markdown]
# # Results
# Question 1. How do the 3 scotch categories perform according to review scores?
#
# Answer: According to the boxplot provided above, it appears that the Blended Malt performed the best, as 50% of the reviews were between 87 and 91. This category has the narrowest distribution of scores. Single Malt and Blended Scotch each have one and/or two 97 scores, but Single Malt has a lower central tendency, and Blended Scotch has greater dispersion of values. Therefore, I crown the title of Best Category to Blended Malt.
#
# Question 2. Which category is produced and sold in the greatest quantity?
#
# Answer: According to the bar plot provided above, single malt scotches are produced in much greater magnitude. Or more accurately, perhaps I should say that single malt whiskys were reviewed much more inside this dataset. Actual production volume and sales could only be inferred from this particular dataset.
#
# Question 3. Which scotches provide the best overall value?
#
# Answer: I approached this question two different ways. The first was just by creating aribtrary values on which to filter the dataset. I wanted to return only bottles that fit two criteria: priced at 125 or less, and rated as 93 or higher. The resulting dataframe returned sorted by review score in descending order. So a user could browse through this dataframe in order to pick the appropriate aperitif. The second method provided a little more direction. I created a new column in the dataframe with the calculation of points / price, in order to normalize 'value'. So the lower the better in this formula, which is how I sorted the dataframe. So a user can now view this dataframe, and if they want the best whisky for their money, then its the Black Bottle 10 year. I'll be on the lookout for that myself.
#
# Question 4. My friend was upset that a particular bottle wasn't in the best values list, so why not?
#
# Answer: I sent this scotch analysis to my friend, desperately hoping for the positive affirmation my self esteem needs. Almost immediately, he asks in an accusatory tone why his two favorite scotches aren't in the file I sent him. His two favorites are Macallan 12 year, and Macallan 18 year. So I searched for them in the original database, and sadly for my friend, those two have ratings between 87 and 92, and since I filtered for any ratings 93 and above, they just missed the cut. And some of them are much more expensive than 125. Sorry bro.

# %% [markdown]
# # Sources
# https://www.kaggle.com/code/neilcosgrove/scotch-whisky-analysis
#
# https://www.kaggle.com/code/fidelissauro/whiskys-common-sense-questions-analysis
#
# https://www.kaggle.com/code/idcargill/linear-regression/notebook
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html#pandas.DataFrame.astype
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html
